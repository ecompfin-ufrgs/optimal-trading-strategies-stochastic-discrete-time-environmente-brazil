# %% [markdown]
# # 03 — Mercado de renda fixa (CDI)
#
# Desenvolve a classe `RendaFixa` (fornece R_f). **F3.**

# %%
import sys, os, tempfile
_cwd = os.getcwd()
RAIZ = os.path.dirname(_cwd) if os.path.basename(_cwd) == 'tests' else _cwd
if RAIZ not in sys.path:
    sys.path.insert(0, RAIZ)

# %% [markdown]
# ## Desenvolvimento
#
# A classe abaixo foi escrita aqui e, após os testes, movida para `app/mercado.py`.

# %%
class RendaFixa:
    """Mercado de renda fixa (CDI) — fornece a taxa livre de risco. (F3)"""

    def __init__(self, cdi_anual: float, periodos_por_ano: int = 12) -> None:
        """
        Parameters
        ----------
        cdi_anual : taxa CDI anual em decimal (ex.: 0.10 para 10% a.a.).
        periodos_por_ano : 12 para dados mensais (default).
        """
        self.cdi_anual = float(cdi_anual)
        self.periodos_por_ano = int(periodos_por_ano)

    def retorno_livre_risco(self) -> float:
        """Taxa livre de risco R_f por período (líquida). (F3)

        Conversão **composta** anual → período:

            R_f = (1 + cdi_anual)^(1/periodos_por_ano) − 1

        Ex.: 10% a.a. mensal ⇒ (1.10)^(1/12) − 1 ≈ 0.007974. O fator *bruto*
        usado ao propagar a riqueza é ``1 + R_f``.
        """
        return (1.0 + self.cdi_anual) ** (1.0 / self.periodos_por_ano) - 1.0

# %% [markdown]
# **Teste** — conversão do CDI anual para R_f mensal.

# %%
rf = RendaFixa(0.10).retorno_livre_risco()
print('CDI 10% a.a. -> R_f mensal =', rf)
assert abs(rf - ((1.10)**(1/12) - 1)) < 1e-15
print('F3 RendaFixa: PASSOU')
# Out:
# CDI 10% a.a. -> R_f mensal = 0.007974140428903764
# F3 RendaFixa: PASSOU

# %%
# diario: 252 pregoes/ano (ida-e-volta exata)
rf_d = RendaFixa(0.1312, 252).retorno_livre_risco()
print('CDI 13.12% a.a. -> R_f diario =', rf_d)
assert abs((1 + rf_d) ** 252 - 1.1312) < 1e-12
assert rf_d < rf                                  # periodo menor => taxa por periodo menor
print('F3 RendaFixa (252 periodos): PASSOU')
# Out:
# CDI 13.12% a.a. -> R_f diario = 0.0004893221241111245
# F3 RendaFixa (252 periodos): PASSOU
